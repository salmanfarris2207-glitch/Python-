# %%
# 1. 51,000

# %%
# 2. 30

# %%
# 3. 720

# %%
# 4. 60 km/h

# %%
# 5. 10

# %%
# 6. 140

# %%
# 7. 42

# %%
# 8. Circle

# %%
# 9. U

# %%
# 10. John

# %%
# 11. Saturday

# %%
# 12. May - (sales = 200)

# %%
# 13. 270

# %%
# 14. 162

# %%
# 15. April

# %%
# 16. 1/2

# %%
# 17. 72,75 and 80

# %%
# 18. 38

# %%
# 19. 18

# %%
# 20. 40%

# %%
# 21. [4,6,8,10]

# %%
# 22. Analytics

# %%
# 23. 20

# %%
# 24. 30
#     [10,20,40]

# %%
# 25. 135

# %%
# STUDENT MARK ANALYSIS

# 1.STD WITH HIGHEST MARK

# marks = {"Anu": 85 , "Rahul": 72 , "Akhil": 91 , "Meera": 65 , "Neha" : 78}
# name = max(marks,key = marks.get)
# print("Top Scorer : ",name)
# a = max(marks.values())
# print("Mark : ",a)
# Out:
# Top Scorer :  Akhil
# Mark :  91

# %%
# 2.STD WITH LOWEST MARK

# marks = {"Anu": 85 , "Rahul": 72 , "Akhil": 91 , "Meera": 65 , "Neha" : 78}
# name = min(marks,key = marks.get)
# print("Name : ",name)
# # a = min(marks.values())
# # print("Mark : ",a)
# mark = marks[name]
# print("Mark : ",mark)
# Out:
# Name :  Meera
# Mark :  65

# %%
# 3.AVERAGE MARKS

# marks = {"Anu": 85 , "Rahul": 72 , "Akhil": 91 , "Meera": 65 , "Neha" : 78}
# avg = sum(marks.values())/len(marks)
# print("Average is ",avg)
# Out:
# Average is  78.2

# %%
# 4.NEW DICT SCORED MORE THAN 75

# marks = {"Anu": 85 , "Rahul": 72 , "Akhil": 91 , "Meera": 65 , "Neha" : 78}
# new = {}
# for nam,mar in marks.items():
#     if mar >= 75:
#         new[nam] = mar
# print("New Dictionary : ",new)
# Out:
# New Dictionary :  {'Anu': 85, 'Akhil': 91, 'Neha': 78}

# %%
# PATTERN PRINTING

# 1.NUMBER PYRAMID

# for i in range(1,5):
#     for j in range(1,i+1):
#         print(j,end="")
#     print()
# for i in range(5,0,-1):
#     for j in range(1,i+1):
#         print(j,end="")
#     print()
# Out:
# 1
# 12
# 123
# 1234
# 12345
# 1234
# 123
# 12
# 1

# %%
# ATM WITHDRAWAL SYSTEM

# bal = 10000
# amt = int(input("Enter withdrawal amount : "))

# if amt <= 0:
#     print("Enter a valid amount.")
# elif amt > bal:
#     print("Insufficient Balance.")
# else:
#     print("Successfull")
#     print(f"Remaining Balance : {bal-amt}")
